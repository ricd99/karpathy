# %%
words = open("names.txt", "r").read().splitlines()

# %%
words[:10]
# Out:
# ['emma',
#  'olivia',
#  'ava',
#  'isabella',
#  'sophia',
#  'charlotte',
#  'mia',
#  'amelia',
#  'harper',
#  'evelyn']

# %%
print(words[0])
for w in words[0]:
    print(type(w))
    print(w)
# Out:
# emma
# <class 'str'>
# e
# <class 'str'>
# m
# <class 'str'>
# m
# <class 'str'>
# a

# %%
print(words[:1])
for w in words[:1]:
    print(type(w))
    print(w)
# Out:
# ['emma']
# <class 'str'>
# emma

# %%
for w in words[:1]:
    for ch1, ch2 in zip(w, w[1:]):
        print(ch1, ch2)
# Out:
# e m
# m m
# m a
